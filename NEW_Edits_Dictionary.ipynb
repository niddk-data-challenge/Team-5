# %%
import pandas as pd

row_list = ['_22Jul2009VisitType',
'_15Aug2011VisitType',
'StorageOfResidualsDuringTrialN',
'WhyAccessingParticipantRecord',
'WhichProtocolVersion2',
'AETerm',
'AECategory',
'AETreatLocation',
'AECausalityByReporter',
'Eventabateafterstoppingdrug',
'CentralIRBOrlocalIRB',
'centralIRBscriteria',
'Followupstatuscode',
'TN01ParticipantStatusSectionB',
'Rbcresults_Units',
'HemoglobinResults_Units',
'HematocritResults_Units',
'MCVresults_Units',
'MCHresults_Units',
'MCHCresults_Units',
'WBCresults_Units',
'NeutrophilsResults_Units',
'NeutrophilsResultsOR_Units',
'LymphocytesResults_Units',
'LymphocytesResultsOR_Units',
'MonocytesResults_Units',
'MonocytesResultsOR_Units',
'EosinophilsResults_Units',
'EosinophilsResultsOR_Units',
'BasophilsResults_Units',
'BasophilsResultsOR_Units',
'IndicateTheStudyParticipantWas',
'IsParticipantCurrentlyEligible',
'IsTheParticipantInterested',
'Havetherebeenanychangesinthepa',
'Participantisahotleadwarmleado',
'TN16TN19TN20EligibilityStatus',
'Pleaseselecttypeofcontactattem',
'FinalContactAttempt1_1',
'Istheparticipantinterestedinth',
'Didtheparticipantindicatetheym',
'Informationgatheredfrom',
'MethodofContact',
'ChangeOfStatusOccuring',
'ReasonForWithdrawal',
'ParticipantWillingToBeContacte',
'DiagnosisBy',
'DiagnosisByOthersSpecify',
'Polyuria',
'PolyuriaMonth',
'Polydipsia',
'PolydipsiaMonth',
'Polyphagia',
'Fatigue',
'UnexplainedWeightLoss',
'Ketoacidosis',
'Units1_1',
'GlucoseType1_1',
'MeasuredBy1_1',
'Units2_1',
'GlucoseType2_1',
'MeasuredBy2_1',
'Units3_1',
'GlucoseType3_1',
'MeasuredBy3_1',
'CriteriaParticipantDiagnosewit',
'H2OvernightHospitalization',
'H3AdmissionToICU',
'H5StartedInsulin',
'NotificationStatus',
'ParticipantContacted',
'ParticipantExpectedToContinue',
'Old_Site_Number',
'Current_Site_Number',
'Reason_for_Transfer',
'PInotified',
'ProtocolDeviation',
'ProtocolDeviationOtherSubcateg',
'SignedConsentFor2017Protocol',
'Medication',
'Units',
'ConMedsFrequencyChoices',
'ConMedsFrequencyOtherDetail',
'ConMedsIntervalChoices',
'ConMedsRoute',
'Indication',
'IsContinuing',
'LowestGlucose_unit',
'SelectTheTrialNetStudyInWhichT',
'SubjectHasSignedWrittenInforme',
'AllowToPutAnyRemainingBloodSam',
'TN16ProtocolDeviation',
'SelectTheVersionOfTN16',
'aereportdt',
'AE_Submitted',
'AEPrimarySecondary',
'AEexpected',
'aeresolvedt',
'AEPatientOutcome',
'Eventreappearafterreintroduct',
'AEReasonForFollowup',
'PhysicalExamFirstVisitYesNo',
'LungsFindings',
'PulsesFindings',
'PubicHairTannerStage',
'ConMedsIntervalOtherDetails',
'ExperiencedAnyHypoglycemicEven',
'VisitProtocolDeviationOccurred',
'ProtocolDeviationReasons',
'PINotified',
'AnyGrade3OrGreaterProblems',
'GCSFWassplenomegalyindicatedon',
'SubcutaneousInjectionGiven',
'ExperienceFollowingProblems',
'ExperienceOtherProblems',
'SpecificGravity',
'PlanPregnantWithinNextYear',
'BirthControlAbstinenceAcceptab',
'Event_Title',
'SampleMaskID',
'Description',
'HBsAb',
'consenttocontinuedstorageofres',
'WastheVolunteerUnderstandingAs',
'Hastheparticipantusedantibioti',
'firstorseconddegreerelativesbe',
'Hasanyoneintheparticipantfamil',
'Hastheparticipanteverbeendiagn',
'DescriptionDeviationCircumstan',
'Havetherebeenanychangesinhealt',
'Havetherebeenanychangesinconco',
'Istheparticipantcurrentlytakin',
'HbA1c_Units',
'willingToConsiderAtALaterTime',
'DateParticipantwascontacted1_2',
'HospitalizedAtDiagnosisTime',
'Date_of_Study_Start',
'Date_of_Diagnosis',
'aedate',
'AEFollowUpDate',
'Date_of_Draw',
'death_date',
'ReviewDate',
'Date_Run',
'Datewritteninformedconsentasse2',
'_22Jul2009ConsentSignedDate',
'_15Aug2011ConsentDateDate',
'Fall2017ConsentDateDate',
'DateStatusChangeDate',
'DoRDate',
'DoWDate',
'DiagnosisDate',
'InsulinTreatmentStartedDate',
'AdmissionDate',
'DischargeDate',
'GlucoseDate1_1',
'GlucoseDate2_1',
'GlucoseDate3_1',
'HbA1cDate',
'ProtcolDeviationDate',
'AssessDateDate',
'StartDateDate',
'StopDateDate',
'InformedConsentDate',
'DateProtocolDeviationDate',
'ContactDateDate',
'DateofAssessmentDate',
'DateCompletionDate',
'F2ClinicalDiagnosisDateDate',
'GAD65H_y',
'CMVVL',
'Dose',
'AnthopometricsWeightKg',
'SeatedArmBloodPressureSystolic',
'SeatedArmBloodPressureDiastoli',
'TemperatureDegreeCelcius',
'HeartRateBPM',
'RespiratoryRateBPM']

column_list = ['Variable_Name', 'Variable_Manipulation', 'Measurement_Unit']
df_new = pd.DataFrame(columns=column_list, index=range(178))

column_name = "Variable_Name"
if len(row_list) == len(df_new):
    df_new[column_name] = row_list
    
column_name = "Variable_Name"
common_values = df_new[df_new[column_name].isin(df[column_name])]
df_new = df_new[~df_new[column_name].isin(common_values[column_name])]

df_new['Variable_Manipulation'] = 'Yes'

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
display(df_new)
# Out:
#                        Variable_Name Variable_Manipulation Measurement_Unit
# 0                _22Jul2009VisitType                   Yes              NaN
# 1                _15Aug2011VisitType                   Yes              NaN
# 2     StorageOfResidualsDuringTrialN                   Yes              NaN
# 3      WhyAccessingParticipantRecord                   Yes              NaN
# 4              WhichProtocolVersion2                   Yes              NaN
# 5                             AETerm                   Yes              NaN
# 6                         AECategory                   Yes              NaN
# 7                    AETreatLocation                   Yes              NaN
# 8              AECausalityByReporter                   Yes              NaN
# 9        Eventabateafterstoppingdrug                   Yes              NaN
# 10              CentralIRBOrlocalIRB                   Yes              NaN
# 11               centralIRBscriteria                   Yes              NaN
# 12                Followupstatuscode                   Yes              NaN
# 13     TN01ParticipantStatusSectionB                   Yes              NaN
# 14                  Rbcresults_Units                   Yes              NaN
# 15           HemoglobinResults_Units                   Yes              NaN
# 16           HematocritResults_Units                   Yes              NaN
# 17                  MCVresults_Units                   Yes              NaN
# 18                  MCHresults_Units                   Yes              NaN
# 19                 MCHCresults_Units                   Yes              NaN
# 20                  WBCresults_Units                   Yes              NaN
# 21          NeutrophilsResults_Units                   Yes              NaN
# 22        NeutrophilsResultsOR_Units                   Yes              NaN
# 23          LymphocytesResults_Units                   Yes              NaN
# 24        LymphocytesResultsOR_Units                   Yes              NaN
# 25            MonocytesResults_Units                   Yes              NaN
# 26          MonocytesResultsOR_Units                   Yes              NaN
# 27          EosinophilsResults_Units                   Yes              NaN
# 28        EosinophilsResultsOR_Units                   Yes              NaN
# 29            BasophilsResults_Units                   Yes              NaN
# 30          BasophilsResultsOR_Units                   Yes              NaN
# 31    IndicateTheStudyParticipantWas                   Yes              NaN
# 32    IsParticipantCurrentlyEligible                   Yes              NaN
# 33        IsTheParticipantInterested                   Yes              NaN
# 34    Havetherebeenanychangesinthepa                   Yes              NaN
# 35    Participantisahotleadwarmleado                   Yes              NaN
# 36     TN16TN19TN20EligibilityStatus                   Yes              NaN
# 37    Pleaseselecttypeofcontactattem                   Yes              NaN
# 38            FinalContactAttempt1_1                   Yes              NaN
# 39    Istheparticipantinterestedinth                   Yes              NaN
# 40    Didtheparticipantindicatetheym                   Yes              NaN
# 41           Informationgatheredfrom                   Yes              NaN
# 42                   MethodofContact                   Yes              NaN
# 43            ChangeOfStatusOccuring                   Yes              NaN
# 44               ReasonForWithdrawal                   Yes              NaN
# 45    ParticipantWillingToBeContacte                   Yes              NaN
# 46                       DiagnosisBy                   Yes              NaN
# 47          DiagnosisByOthersSpecify                   Yes              NaN
# 48                          Polyuria                   Yes              NaN
# 49                     PolyuriaMonth                   Yes              NaN
# 50                        Polydipsia                   Yes              NaN
# 51                   PolydipsiaMonth                   Yes              NaN
# 52                        Polyphagia                   Yes              NaN
# 53                           Fatigue                   Yes              NaN
# 54             UnexplainedWeightLoss                   Yes              NaN
# 55                      Ketoacidosis                   Yes              NaN
# 56                          Units1_1                   Yes              NaN
# 57                    GlucoseType1_1                   Yes              NaN
# 58                     MeasuredBy1_1                   Yes              NaN
# 59                          Units2_1                   Yes              NaN
# 60                    GlucoseType2_1                   Yes              NaN
# 61                     MeasuredBy2_1                   Yes              NaN
# 62                          Units3_1                   Yes              NaN
# 63                    GlucoseType3_1                   Yes              NaN
# 64                     MeasuredBy3_1                   Yes              NaN
# 65    CriteriaParticipantDiagnosewit                   Yes              NaN
# 66        H2OvernightHospitalization                   Yes              NaN
# 67                  H3AdmissionToICU                   Yes              NaN
# 68                  H5StartedInsulin                   Yes              NaN
# 69                NotificationStatus                   Yes              NaN
# 70              ParticipantContacted                   Yes              NaN
# 71     ParticipantExpectedToContinue                   Yes              NaN
# 72                   Old_Site_Number                   Yes              NaN
# 73               Current_Site_Number                   Yes              NaN
# 74               Reason_for_Transfer                   Yes              NaN
# 75                        PInotified                   Yes              NaN
# 76                 ProtocolDeviation                   Yes              NaN
# 77    ProtocolDeviationOtherSubcateg                   Yes              NaN
# 78      SignedConsentFor2017Protocol                   Yes              NaN
# 79                        Medication                   Yes              NaN
# 80                             Units                   Yes              NaN
# 81           ConMedsFrequencyChoices                   Yes              NaN
# 82       ConMedsFrequencyOtherDetail                   Yes              NaN
# 83            ConMedsIntervalChoices                   Yes              NaN
# 84                      ConMedsRoute                   Yes              NaN
# 85                        Indication                   Yes              NaN
# 86                      IsContinuing                   Yes              NaN
# 87                LowestGlucose_unit                   Yes              NaN
# 88    SelectTheTrialNetStudyInWhichT                   Yes              NaN
# 89    SubjectHasSignedWrittenInforme                   Yes              NaN
# 90    AllowToPutAnyRemainingBloodSam                   Yes              NaN
# 91             TN16ProtocolDeviation                   Yes              NaN
# 92            SelectTheVersionOfTN16                   Yes              NaN
# 93                        aereportdt                   Yes              NaN
# 94                      AE_Submitted                   Yes              NaN
# 95                AEPrimarySecondary                   Yes              NaN
# 96                        AEexpected                   Yes              NaN
# 97                       aeresolvedt                   Yes              NaN
# 98                  AEPatientOutcome                   Yes              NaN
# 99     Eventreappearafterreintroduct                   Yes              NaN
# 100              AEReasonForFollowup                   Yes              NaN
# 101      PhysicalExamFirstVisitYesNo                   Yes              NaN
# 102                    LungsFindings                   Yes              NaN
# 103                   PulsesFindings                   Yes              NaN
# 104             PubicHairTannerStage                   Yes              NaN
# 105      ConMedsIntervalOtherDetails                   Yes              NaN
# 106   ExperiencedAnyHypoglycemicEven                   Yes              NaN
# 107   VisitProtocolDeviationOccurred                   Yes              NaN
# 108         ProtocolDeviationReasons                   Yes              NaN
# 109                       PINotified                   Yes              NaN
# 110       AnyGrade3OrGreaterProblems                   Yes              NaN
# 111   GCSFWassplenomegalyindicatedon                   Yes              NaN
# 112       SubcutaneousInjectionGiven                   Yes              NaN
# 113      ExperienceFollowingProblems                   Yes              NaN
# 114          ExperienceOtherProblems                   Yes              NaN
# 115                  SpecificGravity                   Yes              NaN
# 116       PlanPregnantWithinNextYear                   Yes              NaN
# 117   BirthControlAbstinenceAcceptab                   Yes              NaN
# 118                      Event_Title                   Yes              NaN
# 119                     SampleMaskID                   Yes              NaN
# 120                      Description                   Yes              NaN
# 121                            HBsAb                   Yes              NaN
# 122   consenttocontinuedstorageofres                   Yes              NaN
# 123   WastheVolunteerUnderstandingAs                   Yes              NaN
# 124   Hastheparticipantusedantibioti                   Yes              NaN
# 125   firstorseconddegreerelativesbe                   Yes              NaN
# 126   Hasanyoneintheparticipantfamil                   Yes              NaN
# 127   Hastheparticipanteverbeendiagn                   Yes              NaN
# 128   DescriptionDeviationCircumstan                   Yes              NaN
# 129   Havetherebeenanychangesinhealt                   Yes              NaN
# 130   Havetherebeenanychangesinconco                   Yes              NaN
# 131   Istheparticipantcurrentlytakin                   Yes              NaN
# 132                      HbA1c_Units                   Yes              NaN
# 133    willingToConsiderAtALaterTime                   Yes              NaN
# 134   DateParticipantwascontacted1_2                   Yes              NaN
# 135      HospitalizedAtDiagnosisTime                   Yes              NaN
# 136              Date_of_Study_Start                   Yes              NaN
# 137                Date_of_Diagnosis                   Yes              NaN
# 138                           aedate                   Yes              NaN
# 139                   AEFollowUpDate                   Yes              NaN
# 140                     Date_of_Draw                   Yes              NaN
# 141                       death_date                   Yes              NaN
# 142                       ReviewDate                   Yes              NaN
# 143                         Date_Run                   Yes              NaN
# 144  Datewritteninformedconsentasse2                   Yes              NaN
# 145      _22Jul2009ConsentSignedDate                   Yes              NaN
# 146        _15Aug2011ConsentDateDate                   Yes              NaN
# 147          Fall2017ConsentDateDate                   Yes              NaN
# 148             DateStatusChangeDate                   Yes              NaN
# 149                          DoRDate                   Yes              NaN
# 150                          DoWDate                   Yes              NaN
# 151                    DiagnosisDate                   Yes              NaN
# 152      InsulinTreatmentStartedDate                   Yes              NaN
# 153                    AdmissionDate                   Yes              NaN
# 154                    DischargeDate                   Yes              NaN
# 155                   GlucoseDate1_1                   Yes              NaN
# 156                   GlucoseDate2_1                   Yes              NaN
# 157                   GlucoseDate3_1                   Yes              NaN
# 158                        HbA1cDate                   Yes              NaN
# 159             ProtcolDeviationDate                   Yes              NaN
# 160                   AssessDateDate                   Yes              NaN
# 161                    StartDateDate                   Yes              NaN
# 162                     StopDateDate                   Yes              NaN
# 163              InformedConsentDate                   Yes              NaN
# 164        DateProtocolDeviationDate                   Yes              NaN
# 165                  ContactDateDate                   Yes              NaN
# 166             DateofAssessmentDate                   Yes              NaN
# 167               DateCompletionDate                   Yes              NaN
# 168      F2ClinicalDiagnosisDateDate                   Yes              NaN
# 169                         GAD65H_y                   Yes              NaN
# 170                            CMVVL                   Yes              NaN
# 171                             Dose                   Yes              NaN
# 172           AnthopometricsWeightKg                   Yes              NaN
# 173   SeatedArmBloodPressureSystolic                   Yes              NaN
# 174   SeatedArmBloodPressureDiastoli                   Yes              NaN
# 175         TemperatureDegreeCelcius                   Yes              NaN
# 176                     HeartRateBPM                   Yes              NaN
# 177               RespiratoryRateBPM                   Yes              NaN

# %%
df_new.loc[df_new['Variable_Name'] == 'HeartRateBPM', 'Measurement_Unit'] = 'Beats/minute'
df_new.loc[df_new['Variable_Name'] == 'RespiratoryRateBPM', 'Measurement_Unit'] = 'Breaths/minute'
df_new.loc[df_new['Variable_Name'] == 'SeatedArmBloodPressureSystolic', 'Measurement_Unit'] = 'mmHg'
df_new.loc[df_new['Variable_Name'] == 'SeatedArmBloodPressureDiastoli', 'Measurement_Unit'] = 'mmHg'
df_new.loc[df_new['Variable_Name'] == 'TemperatureDegreeCelcius', 'Measurement_Unit'] = 'Degrees Celsius'
df_new.loc[df_new['Variable_Name'] == 'Rbcresults_Units', 'Measurement_Unit'] = 'x10^12 cells/L'
df_new.loc[df_new['Variable_Name'] == 'HemoglobinResults_Units', 'Measurement_Unit'] = 'mg/dL'
df_new.loc[df_new['Variable_Name'] == 'HematocritResults_Units', 'Measurement_Unit'] = '% of blood'
df_new.loc[df_new['Variable_Name'] == 'MCVresults_Units', 'Measurement_Unit'] = 'fL'
df_new.loc[df_new['Variable_Name'] == 'MCHresults_Units', 'Measurement_Unit'] = 'pg'
df_new.loc[df_new['Variable_Name'] == 'MCHCresults_Units', 'Measurement_Unit'] = 'g/dL'
df_new.loc[df_new['Variable_Name'] == 'WBCresults_Units', 'Measurement_Unit'] = 'x10^9 cells/L'
df_new.loc[df_new['Variable_Name'] == 'NeutrophilsResults_Units', 'Measurement_Unit'] = '% of WBC'
df_new.loc[df_new['Variable_Name'] == 'LymphocytesResults_Units', 'Measurement_Unit'] = '% of WBC'
df_new.loc[df_new['Variable_Name'] == 'MonocytesResults_Units', 'Measurement_Unit'] = '% of WBC'
df_new.loc[df_new['Variable_Name'] == 'MonocytesResultsOR_Units', 'Measurement_Unit'] = '% of WBC'
df_new.loc[df_new['Variable_Name'] == 'EosinophilsResults_Units', 'Measurement_Unit'] = '% of WBC'
df_new.loc[df_new['Variable_Name'] == 'EosinophilsResultsOR_Units', 'Measurement_Unit'] = '% of WBC'
df_new.loc[df_new['Variable_Name'] == 'BasophilsResults_Units', 'Measurement_Unit'] = '% of WBC'
df_new.loc[df_new['Variable_Name'] == 'BasophilsResultsOR_Units', 'Measurement_Unit'] = '% of WBC'
df_new.loc[df_new['Variable_Name'] == 'HbA1c_Units', 'Measurement_Unit'] = 'Hb%'


df_new.loc[df_new['Variable_Name'] == 'SampleMaskID', 'Variable_Manipulation'] = 'No'

# %%
var_name_list = df_new['Variable_Name'].tolist()
print(var_name_list)

print('')
print('')
print('')

var_manipulation_list = df_new['Variable_Manipulation'].tolist()
print(var_manipulation_list)

print('')
print('')
print('')

unit_list = df_new['Measurement_Unit'].tolist()
print(unit_list)
# Out:
# ['_22Jul2009VisitType', '_15Aug2011VisitType', 'StorageOfResidualsDuringTrialN', 'WhyAccessingParticipantRecord', 'WhichProtocolVersion2', 'AETerm', 'AECategory', 'AETreatLocation', 'AECausalityByReporter', 'Eventabateafterstoppingdrug', 'CentralIRBOrlocalIRB', 'centralIRBscriteria', 'Followupstatuscode', 'TN01ParticipantStatusSectionB', 'Rbcresults_Units', 'HemoglobinResults_Units', 'HematocritResults_Units', 'MCVresults_Units', 'MCHresults_Units', 'MCHCresults_Units', 'WBCresults_Units', 'NeutrophilsResults_Units', 'NeutrophilsResultsOR_Units', 'LymphocytesResults_Units', 'LymphocytesResultsOR_Units', 'MonocytesResults_Units', 'MonocytesResultsOR_Units', 'EosinophilsResults_Units', 'EosinophilsResultsOR_Units', 'BasophilsResults_Units', 'BasophilsResultsOR_Units', 'IndicateTheStudyParticipantWas', 'IsParticipantCurrentlyEligible', 'IsTheParticipantInterested', 'Havetherebeenanychangesinthepa', 'Participantisahotleadwarmleado', 'TN16TN19TN20EligibilityStatus', 'Pleaseselecttypeofcontactattem', 'FinalContactAttempt1_1', 'Istheparticipantinterestedinth', 'Didtheparticipantindicatetheym', 'Informationgatheredfrom', 'MethodofContact', 'ChangeOfStatusOccuring', 'ReasonForWithdrawal', 'ParticipantWillingToBeContacte', 'DiagnosisBy', 'DiagnosisByOthersSpecify', 'Polyuria', 'PolyuriaMonth', 'Polydipsia', 'PolydipsiaMonth', 'Polyphagia', 'Fatigue', 'UnexplainedWeightLoss', 'Ketoacidosis', 'Units1_1', 'GlucoseType1_1', 'MeasuredBy1_1', 'Units2_1', 'GlucoseType2_1', 'MeasuredBy2_1', 'Units3_1', 'GlucoseType3_1', 'MeasuredBy3_1', 'CriteriaParticipantDiagnosewit', 'H2OvernightHospitalization', 'H3AdmissionToICU', 'H5StartedInsulin', 'NotificationStatus', 'ParticipantContacted', 'ParticipantExpectedToContinue', 'Old_Site_Number', 'Current_Site_Number', 'Reason_for_Transfer', 'PInotified', 'ProtocolDeviation', 'ProtocolDeviationOtherSubcateg', 'SignedConsentFor2017Protocol', 'Medication', 'Units', 'ConMedsFrequencyChoices', 'ConMedsFrequencyOtherDetail', 'ConMedsIntervalChoices', 'ConMedsRoute', 'Indication', 'IsContinuing', 'LowestGlucose_unit', 'SelectTheTrialNetStudyInWhichT', 'SubjectHasSignedWrittenInforme', 'AllowToPutAnyRemainingBloodSam', 'TN16ProtocolDeviation', 'SelectTheVersionOfTN16', 'aereportdt', 'AE_Submitted', 'AEPrimarySecondary', 'AEexpected', 'aeresolvedt', 'AEPatientOutcome', 'Eventreappearafterreintroduct', 'AEReasonForFollowup', 'PhysicalExamFirstVisitYesNo', 'LungsFindings', 'PulsesFindings', 'PubicHairTannerStage', 'ConMedsIntervalOtherDetails', 'ExperiencedAnyHypoglycemicEven', 'VisitProtocolDeviationOccurred', 'ProtocolDeviationReasons', 'PINotified', 'AnyGrade3OrGreaterProblems', 'GCSFWassplenomegalyindicatedon', 'SubcutaneousInjectionGiven', 'ExperienceFollowingProblems', 'ExperienceOtherProblems', 'SpecificGravity', 'PlanPregnantWithinNextYear', 'BirthControlAbstinenceAcceptab', 'Event_Title', 'SampleMaskID', 'Description', 'HBsAb', 'consenttocontinuedstorageofres', 'WastheVolunteerUnderstandingAs', 'Hastheparticipantusedantibioti', 'firstorseconddegreerelativesbe', 'Hasanyoneintheparticipantfamil', 'Hastheparticipanteverbeendiagn', 'DescriptionDeviationCircumstan', 'Havetherebeenanychangesinhealt', 'Havetherebeenanychangesinconco', 'Istheparticipantcurrentlytakin', 'HbA1c_Units', 'willingToConsiderAtALaterTime', 'DateParticipantwascontacted1_2', 'HospitalizedAtDiagnosisTime', 'Date_of_Study_Start', 'Date_of_Diagnosis', 'aedate', 'AEFollowUpDate', 'Date_of_Draw', 'death_date', 'ReviewDate', 'Date_Run', 'Datewritteninformedconsentasse2', '_22Jul2009ConsentSignedDate', '_15Aug2011ConsentDateDate', 'Fall2017ConsentDateDate', 'DateStatusChangeDate', 'DoRDate', 'DoWDate', 'DiagnosisDate', 'InsulinTreatmentStartedDate', 'AdmissionDate', 'DischargeDate', 'GlucoseDate1_1', 'GlucoseDate2_1', 'GlucoseDate3_1', 'HbA1cDate', 'ProtcolDeviationDate', 'AssessDateDate', 'StartDateDate', 'StopDateDate', 'InformedConsentDate', 'DateProtocolDeviationDate', 'ContactDateDate', 'DateofAssessmentDate', 'DateCompletionDate', 'F2Clinica ...
#
#
#
# ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes']
#
#
#
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'x10^12 cells/L', 'mg/dL', '% of blood', 'fL', 'pg', 'g/dL', 'x10^9 cells/L', '% of WBC', nan, '% of WBC', nan, '% of WBC', '% of WBC', '% of WBC', '% of WBC', '% of WBC', '% of WBC', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'Hb%', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'mmHg', 'mmHg', 'Degrees Celsius', 'Beats/minute', 'Breaths/minute']

# %%
## Most recent as of 1/18 10:00am

import pandas as pd

file = "/home/ec2-user/SageMaker/Team-5/Variable Manipulation.csv"
df = pd.read_csv(file)

# %%
df = df.rename(columns={'LowestGlucose_unitl': 'LowestGlucose_unit'})

new_column = 'Measurement_Unit'
df[new_column] = pd.Series(['NaN'] * len(df), dtype='object')

df.loc[df['Variable_Name'] == 'Height_cm', new_column] = 'cm'
df.loc[df['Variable_Name'] == 'HeightCm', new_column] = 'cm'
df.loc[df['Variable_Name'] == 'Height_cm_units', new_column] = 'cm'

df.loc[df['Variable_Name'] == 'Weight_kg', new_column] = 'kg'
df.loc[df['Variable_Name'] == 'WeightKg', new_column] = 'kg'
df.loc[df['Variable_Name'] == 'Weight_kg_units', new_column] = 'kg'

df.loc[df['Variable_Name'] == 'AvgRecordedFastingGlucoses', new_column] = 'mg/dL'
df.loc[df['Variable_Name'] == 'AvgAllRecordedGlucoses', new_column] = 'mg/dL'
df.loc[df['Variable_Name'] == 'LowestGlucose', new_column] = 'mg/dL'
df.loc[df['Variable_Name'] == 'HighestGlucose', new_column] = 'mg/dL'

df.loc[df['Variable_Name'] == 'AvgRecordedFastingGlucoses_unit', new_column] = 'mg/dL'
df.loc[df['Variable_Name'] == 'AvgAllRecordedGlucoses_unit', new_column] = 'mg/dL'
df.loc[df['Variable_Name'] == 'LowestGlucose_unit', new_column] = 'mg/dL'
df.loc[df['Variable_Name'] == 'HighestGlucose_unit', new_column] = 'mg/dL'

df.loc[df['Variable_Name'] == 'MCHresults', new_column] = 'pg'
df.loc[df['Variable_Name'] == 'MCHCresults', new_column] = 'g/dL'
df.loc[df['Variable_Name'] == 'EosinophilsResults', new_column] = '% of WBC'
df.loc[df['Variable_Name'] == 'BasophilResults', new_column] = '% of WBC'
df.loc[df['Variable_Name'] == 'LymphocytesResults', new_column] = '% of WBC'
df.loc[df['Variable_Name'] == 'HemoglobinResults', new_column] = 'mg/dL'
df.loc[df['Variable_Name'] == 'HematocritResults', new_column] = '% of blood'
df.loc[df['Variable_Name'] == 'MCVresults', new_column] = 'fL'
df.loc[df['Variable_Name'] == 'MonocytesResults', new_column] = '% of WBC'
df.loc[df['Variable_Name'] == 'NeutrophilsResults', new_column] = '% of WBC'
df.loc[df['Variable_Name'] == 'WBCresults', new_column] = 'x10^9 cells/L'
df.loc[df['Variable_Name'] == 'Rbcresults', new_column] = 'x10^12 cells/L'

df.loc[df['Variable_Name'] == 'EosinophilsResultsOR', new_column] = '% of WBC'
df.loc[df['Variable_Name'] == 'LymphocytesResultsOR', new_column] = '% of WBC'
df.loc[df['Variable_Name'] == 'BasophilResults', new_column] = '% of WBC'





display(df)
# Out:
#                                         Variable_Name Variable_Manipulation  \
# 0                                            Visit_Dt                    No
# 1                      DateResultsReportedByLabUnknow                    No
# 2                                    RBCResultsNormal                   Yes
# 3                             HemoglobinResultsNormal                   Yes
# 4                             HematocritResultsNormal                   Yes
# 5                                    MCVresultsNormal                   Yes
# 6                         PlateletCountResultsNormal2                   Yes
# 7                                    MCHresultsNormal                   Yes
# 8                                   MCHCresultsNormal                   Yes
# 9                                    WBCresultsNormal                   Yes
# 10                           NeutrophilsResultsNormal                   Yes
# ...

# %%
var_name_list = df['Variable_Name'].tolist()
print(var_name_list)

print('')
print('')
print('')

var_manipulation_list = df['Variable_Manipulation'].tolist()
print(var_manipulation_list)

print('')
print('')
print('')

unit_list = df['Measurement_Unit'].tolist()
print(unit_list)
# Out:
# ['Visit_Dt', 'DateResultsReportedByLabUnknow', 'RBCResultsNormal', 'HemoglobinResultsNormal', 'HematocritResultsNormal', 'MCVresultsNormal', 'PlateletCountResultsNormal2', 'MCHresultsNormal', 'MCHCresultsNormal', 'WBCresultsNormal', 'NeutrophilsResultsNormal', 'LymphocytesResultsNormal', 'MonocytesResultsNormal', 'EosinophilsResultsNormal', 'BasophilsResultsNormal', 'Hastheparticipantbeentoahealth', 'Hastheparticipanthadafever', 'Hastheparticipanthadchillsasso', 'Hastheparticipanthadacough', 'Hastheparticipanthadanydifficu', 'Hastheparticipanthadanypersist', 'Hastheparticipantexperiencedvo', '_8Hastheparticipantbeendiagnos', 'Visit_Type', 'Age', 'RelativeWithT1D', 'DegreeOfRelative_2ndor3rd', 'HaveDiabetes', 'Sex', 'Race_Asian', 'Race_BlackorAfricanAmerican', 'Race_NativeHawaiianorOtherPaci', 'Race_Refused', 'Race_Unknownornotreported', 'Race_White', 'Relationship', 'FirstHearAboutTrialN_FamilyFrien', 'FirstHearAboutTrialN_Healthcarep', 'FirstHearAboutTrialN_Tollfreepho', 'FirstHearA
# ...

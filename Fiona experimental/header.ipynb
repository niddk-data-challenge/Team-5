# %%
import pickle
with open('headers.pickle', 'rb') as file:
    headers = pickle.load(file)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
header=[]
for i in headers:
    header.append(i)
    print(i)
# Out:
# MaskID
# Visit
# Visit_Dt
# _15Aug2011ConsentForResidualSa
# WhichProtocolVersion
# ProtocolVersion
# DateResultsReportedByLabUnknow
# RBCResultsNormal
# RBCResultAbormalClinicallySign
# HemoglobinResultsNormal
# HemoglobinResultAbormalClinica
# HematocritResultsNormal
# HematocritResultAbormalClinica
# MCVresultsNormal
# MCVResultAbormalClinicallySign
# PlateletCountResultsNormal2
# MCHresultsNormal
# MCHResultAbormalClinicallySign
# MCHCresultsNormal
# WBCresultsNormal
# WBCResultAbormalClinicallySign
# NeutrophilsResultsNormal
# NeutrophilsResultAbormalClinic
# LymphocytesResultsNormal
# LymphocytesResultAbormalClinic
# MonocytesResultsNormal
# MonocytesResultAbormalClinical
# EosinophilsResultsNormal
# EosinophilsResultAbormalClinic
# BasophilsResultsNormal
# Hastheparticipantbeentoahealth
# Hastheparticipanthadknownconta
# Hastheparticipanthadknownconta2
# Hastheparticipantbeentestedfor
# Hastheparticipanthadafever
# Hastheparticipanthadchillsasso
# Hastheparticipanthadacough
# ...

# %%
header

# %%
a=['MaskID',
 'Visit',
 'Visit_Dt',
 '_15Aug2011ConsentForResidualSa',
 'WhichProtocolVersion',
 'ProtocolVersion',
 'DateResultsReportedByLabUnknow',
 'RBCResultsNormal',
 'RBCResultAbormalClinicallySign',
 'HemoglobinResultsNormal',
 'HemoglobinResultAbormalClinica',
 'HematocritResultsNormal',
 'HematocritResultAbormalClinica',
 'MCVresultsNormal',
 'MCVResultAbormalClinicallySign',
 'PlateletCountResultsNormal2',
 'MCHresultsNormal',
 'MCHResultAbormalClinicallySign',
 'MCHCresultsNormal',
 'WBCresultsNormal',
 'WBCResultAbormalClinicallySign',
 'NeutrophilsResultsNormal',
 'NeutrophilsResultAbormalClinic',
 'LymphocytesResultsNormal',
 'LymphocytesResultAbormalClinic',
 'MonocytesResultsNormal',
 'MonocytesResultAbormalClinical',
 'EosinophilsResultsNormal',
 'EosinophilsResultAbormalClinic',
 'BasophilsResultsNormal',
 'Hastheparticipantbeentoahealth',
 'Hastheparticipanthadknownconta',
 'Hastheparticipanthadknownconta2',
 'Hastheparticipantbeentestedfor',
 'Hastheparticipanthadafever',
 'Hastheparticipanthadchillsasso',
 'Hastheparticipanthadacough',
 'Hastheparticipanthadanydifficu',
 'Hastheparticipanthadanypersist',
 'Hastheparticipanthadalossreduc',
 'Hastheparticipantexperiencedvo',
 '_8Hastheparticipantbeendiagnos',
 'Visit_Type',
 'Age',
 'RelativeWithT1D',
 'DegreeOfRelative_1st',
 'DegreeOfRelative_2ndor3rd',
 'HaveDiabetes',
 'ParticipantLocation',
 'Sex',
 'Ethnicity',
 'Race_AmericanIndianorAlaskaNat',
 'Race_Asian',
 'Race_BlackorAfricanAmerican',
 'Race_NativeHawaiianorOtherPaci',
 'Race_Refused',
 'Race_Unknownornotreported',
 'Race_White',
 'Relationship',
 'FirstHearAboutTrialN_ExistingTri',
 'FirstHearAboutTrialN_FamilyFrien',
 'FirstHearAboutTrialN_Brochure',
 'FirstHearAboutTrialN_Healthcarep',
 'FirstHearAboutTrialN_Tollfreepho',
 'FirstHearAboutTrialN_NewspaperMa',
 'FirstHearAboutTrialN_Poster',
 'FirstHearAboutTrialN_Camp',
 'FirstHearAboutTrialN_MeetingPres',
 'FirstHearAboutTrialN_RadioTV',
 'FirstHearAboutTrialN_Internet',
 'FirstHearAboutTrialN_Other',
 'InitialScreeningLocation',
 'InitialScreeningLocationOtherS',
 'BloodSamplesFutureTestingPermi',
 'BloodTestForFindOut',
 'CommunicationWhenNegAutoantibo',
 'InformedTestResultWithin',
 'PermissionToControlIfTheyTestA',
 'participanthaveautoantibodies',
 'OnlineScreeningReferralSource',
 'clinicalcenternumber',
 'ScreeningSiteName',
 'ScreeningSiteNumber',
 'shipspecimencollectionkit',
 'Specimencollectionkitshipmentd',
 'selecttestkittype',
 'NumOfRelativesWithT1D',
 'RelativeWithT1D1_1',
 'SexOfRelativeWithT1D1_1',
 'AgeOfRelativeWithT1D1_1',
 'AgeOfOnsetInRelativeWithT1D1_1',
 'AgeRelativeWithT1DStartedIn1_1',
 'RelativeWithT1D2_1',
 'SexOfRelativeWithT1D2_1',
 'AgeOfRelativeWithT1D2_1',
 'AgeOfOnsetInRelativeWithT1D2_1',
 'AgeRelativeWithT1DStartedIn2_1',
 'RelativeWithT1D3_1',
 'SexOfRelativeWithT1D3_1',
 'AgeOfRelativeWithT1D3_1',
 'AgeOfOnsetInRelativeWithT1D3_1',
 'AgeRelativeWithT1DStartedIn3_1',
 'RelativeWithT1D4_1',
 'SexOfRelativeWithT1D4_1',
 'AgeOfRelativeWithT1D4_1',
 'AgeOfOnsetInRelativeWithT1D4_1',
 'AgeRelativeWithT1DStartedIn4_1',
 'RelativeWithT1D5_1',
 'SexOfRelativeWithT1D5_1',
 'RelativeWithT1D6_1',
 'SexOfRelativeWithT1D6_1',
 'RelativeWithT1D7_1',
 'SexOfRelativeWithT1D7_1',
 'SexOfRelativeWithT1D8_1',
 'ParticipantDiagnosedWithT1D',
 'ParticipantUsedInsulinOrOtherG',
 'ParticipantHasKnownSevereActiv',
 'ParticipantPregnant',
 'PermissionForHLAgeneticTesting',
 'PermissionForSampleStorage',
 'AsthmaEver',
 'AsthmaWithinLastYear',
 'CeliacDiseaseEver',
 'CeliacDiseaseWithinLastYear',
 'InflammatoryBowelDiseaseEver',
 'InflammatoryBowelDiseaseWithin',
 'AddisonsDiseaseEver',
 'AddisonsDiseaseWithinLastYear',
 'VitiligoEver',
 'VitiligoWithinLastYear',
 'ThyroidDiseaseEver',
 'ThyroidDiseaseWithinLastYear',
 'PsoriasisEver',
 'PsoriasisWithinLastYear',
 'AlopeciaEver',
 'AlopeciaWithinLastYear',
 'RheumatologicEver',
 'RheumatologicWithinLastYear',
 'MultipleSclerosisEver',
 'MultipleSclerosisWithinLastYea',
 'OtherAutoimmuneDiseasesEver',
 'OtherAutoimmuneDiseasesWithinL',
 'SeatedArmBPSystolic',
 'SeatedArmBPDiastolic',
 'EverParticipatedInPreventionSt',
 'ParticipateInDPT1',
 'AllergiesEver',
 'AllergiesWithinLastYear',
 'AntibodySampleCollected',
 'BetaBlockers',
 'BllodForDNASampleCollected',
 'BloodForCellsSampleCollected',
 'BloodForRNASampleCollected',
 'CancerEver',
 'CancerWithinLastYear',
 'ColitisOrColonProblemsEver',
 'ColitisOrColonProblemsWithinLa',
 'CongenitalHeartDiseaseEver',
 'CongenitalHeartDiseaseWithinLa',
 'ConsenToContinuedStorageOfBloo',
 'Corticosteroids',
 'Diphenylhydantoin',
 'EpilepsyConvulsionsSeizuresEve',
 'EpilepsyConvulsionsSeizuresWit',
 'HLASamplesCollected',
 'HbA1cSamplesCollected',
 'HepatitisOrLiverDiseaseEver',
 'HepatitisOrLiverDiseaseWithinL',
 'HighBPever',
 'HighBPwithinLastYear',
 'HighcholesterolEver',
 'IVGTTSampleCollected',
 'ImmunosuppressiveTherapies',
 'InfectiousMononucleosisEver',
 'InfectiousMononucleosisWithinL',
 'Niacin',
 'OGTTSampleCollected',
 'ParticipantHasOneRelativeWithT',
 'ParticipantUsedImmunosuppresiv',
 'ParticipantUsingImmunosuppresi',
 'PerniciousAnemiaEver',
 'PerniciousAnemiaWithinLastYear',
 'PlasmaSampleCollected',
 'PotassiumDepletingDiurectics',
 'SerumForProteomicsSampleCollec',
 'UlcerEver',
 'UlcerWithinLastYear',
 'SelectStudyForPreventionOfT1D',
 'TestingPlaceForAutoAntibodyOut',
 'IsHeightMeasured',
 'IsWeightMeasured',
 'SeatedHeartRate',
 'SeatedRespiratoryRate',
 'LimitedLifeExpectancyOrImmunos',
 'AsthmaWithinLast6Months',
 'CeliacDiseaseWithinLast6Months',
 'AddisonsDiseaseWithinLast6Months',
 'VitiligoWithinLast6Months',
 'ThyroidDiseaseWithinLast6Months',
 'PsoriasisWithinLast6Months',
 'AlopeciaWithinLast6Months',
 'RheumatologicWithinLast6Months',
 'AllergiesWithinLast6Months',
 'CancerWithinLast6Months',
 'UlcerWithinLast6Months',
 'HighBPwithinLast6Months',
 'PerniciousAnemiaWithinLast6Mo',
 'MultipleSclerosisWithinLast6Mo',
 'hyperglycemia',
 'immunomodulatory',
 'systemicsteroids',
 'Metformin',
 'Thiazolidinediones',
 'AlphaGlucosidaseInhibitors',
 'OtherGlucoseLoweringAgents',
 'SerumMechanisticSerumSampleCol',
 'WholeBloodPBMCPlasmaSampleColl',
 'participantdiagnosedT1D',
 'IsParticipantPregnant',
 'SignedMonitoringConsentProtoco',
 'HighCholesterolWithinLast6Months',
 'Meglitinides',
 'HighCholestrolWithinLast6Months',
 'Meglinitides',
 'CurrentPhase',
 'Date_of_Registration',
 'Status',
 'HospitalizedSinceLastVisit',
 'OtherChronicDiseases',
 'HaveHadComplicationsFromYourDi',
 'HowIsWeightObtained',
 'HowIsHeightObtained',
 'SubjectUsingCGMS',
 'AreThere3GlucoseValuesAvailabl',
 'InsulDoseInfoAvailableFor3Days',
 'AvgRecordedFastingGlucoses_unit',
 'AvgAllRecordedGlucoses_unit',
 'LowestGlucose_unitl',
 'HighestGlucose_unit',
 'InsulinRoutineDaily',
 'RememberDateOfMostRecentHbA1c',
 'RememberValueOfMostRecentHbA1c',
 'SeizuresFaintingLowBloodGlucos',
 'HospitalizationsForHighGlucose',
 'RequiredSpecimensCollected',
 'IfSpecimensNotCollec_Other',
 'OGTTCollected',
 'MMTTCollected',
 'AreYouUsingInjections',
 'InsulinPump',
 'DiagnosedAutoImmuneDisease',
 'Asthma',
 'Allergies',
 'Eczema',
 'OtherInfections',
 'Other',
 'HeentFindings',
 'NeckThyroidFindings',
 'HeartFindings',
 'MusculoskeletalFindings',
 'GenitaliaFindings',
 'AbdomenFindings',
 'LymphaticsFindings',
 'SkinFindings',
 'NeurologicFindings',
 'OtherFindings',
 'ReproductiveChildbearingPotent',
 'UrinePregnancyTest',
 'UrinePregnancyTestPositive',
 'PlateletCountNotDone',
 'MCHNotDone',
 'MCHCNotDone',
 'NeutrophilsNotDone',
 'LymphocytesNotDone',
 'MonocytesNotDone',
 'EosinophilsNotDone',
 'BasophilsNotDone',
 'DateOfRegistration',
 'Subject18',
 'ReceivedInfluenzaVaccination',
 'EvidenceOfTuberculosisInfectio',
 'UseImmunosuppressiveAgents',
 'ComplicatedMedIssuesOrAbnormal',
 'Gender',
 'CollectBloodSamples',
 'EligibileToBeScreenedForTheStu',
 'SexGenderPerson',
 'HospitalizedOtherthanDiabetes',
 'DiabeticKetoacidosisTimeOfDiag',
 'AdmittedHospitalDiagnosis',
 'IGRATestPositive',
 'PregTestPos',
 'FebrileIllness10Days',
 'ExacerbationOfCRS',
 'FeverPresent',
 'SkinRashHypersentivityPresent',
 'FatigueMalaisePresent',
 'DizyLightHeadedPresent',
 'NauseeVomitPresent',
 'HypotensionPresent',
 'HypertensionPresent',
 'HeadcahePresent',
 'IVinfiltrationPresent',
 'InfusionRelatedEventAnaphylaxi',
 'InfusionRelatedEventOther',
 'FullDoseInfused',
 'AnyProblemsRecievingStudyDrugt',
 'AcetaminophenGivenToParticipan',
 'MethylprednisoneGivenDoseTimeM',
 'DiphenhydramineDoseGiven',
 'AnyOtherMedications',
 'Color',
 'Appearance',
 'Leukocytes',
 'Nitrite',
 'Protein',
 'Glucose',
 'Ketones',
 'Urobilinogen',
 'Bilirubin',
 'Blood',
 'Rbcnotdone',
 'HemoglobinNotDone',
 'HematocritNotDone',
 'MCVNotDone',
 'WBCNotDone',
 'Doestheparticipanthavereproduc',
 'Wasaurinepregnancytestcomplete',
 'Wasthetestresultpositive',
 'bloodpressureDiastolicNotDone',
 'WeightNotDone',
 'HeightNotDone',
 'Wasaphysicalexamperformedatthi',
 'HEENT',
 'NeckThyroid',
 'Heart',
 'Lungs',
 'Pulses',
 'Musculoskeletal',
 'Genitalia',
 'Abdomen',
 'Lymphatics',
 'Skin',
 'Neurologic',
 'GivenStudyDrugDoseInClinic',
 'SignsOfHypoglycemia',
 'OtherProblems',
 'StudyDrugReturned',
 'StudyDrugDispensed',
 'ParticipantReceiveStudyDrug',
 'MedicationPackNumber1_1',
 'LotNumber1_1',
 'MedicationPackNumber2_1',
 'LotNumber2_1',
 'MedicationPackNumber3_1',
 'LotNumber3_1',
 'UnusualCircumstances',
 'STHavetherebeenanychangesinhea',
 'STHavetherebeenanychangesincon',
 'STIstheparticipantcurrentlytak',
 'STWastheparticipantcontactedat',
 'INST-10',
 'PEP120',
 'GLU60',
 'PEP60',
 'INST0',
 'INST60',
 'GLU30',
 'PEP30',
 'INST30',
 'GLU0',
 'HbA1c',
 'PEP0',
 'INST120',
 'GLU-10',
 'GLU90',
 'PEP-10',
 'PEP90',
 'GLU120',
 'INST90',
 'GLU15',
 'PEP15',
 'PEP240',
 'GLU240',
 'ZNT8',
 'ICA',
 'PEP150',
 'GLU180',
 'IA-2H',
 'GAD65H',
 'PEP180',
 'GLU150',
 'PEP210',
 'MIAA',
 'EBVVL',
 'GLU210',
 'CD8P',
 'CD8A',
 'CD4P',
 'CD4CD8',
 'CD4A',
 'TPRO',
 'TBIL',
 'SOD',
 'POT',
 'GLU',
 'GLOIgG',
 'DBIL',
 'CREA',
 'CHL',
 'BIC',
 'ALT',
 'ALP',
 'ALB',
 'UREA',
 'AST',
 'CPEP',
 'INST',
 'ICA512',
 'GAD65',
 'INS0',
 'INS120',
 'INS-10',
 'INS60',
 'INS30',
 'INS90',
 'Height_cm_units',
 'Weight_kg_units',
 'Spring2019ConsentDateDate',
 'DateOfBloodDrawDate',
 'DateReportedDate',
 'ScreeningDate',
 'ConsentSignedDate',
 'DateConsentSignedDate',
 'SamplesCollectionDate',
 'LastHbA1cDate',
 'WrittenInformedConsentDate',
 'Type1DiabetesDiagnosisDate',
 'FluVaccinationDateDate',
 'DateTestsRunDate',
 'StudyDrugReturnedDate',
 'StudyDrugDispensedDate',
 'BirthDate',
 'DateOfBirthDate',
 'HbA1crecordDateDate',
 'DateRecordedDate1',
 'DateRecordedDate2',
 'DateRecordedDate3',
 'ParticipantDateDispensedDate1_1',
 'ParticipantDateDispensedDate2_1',
 'ParticipantDateDispensedDate3_1',
 'MechanisticSampleCollectionDate',
 'DateSignedInformedConsentFormDate',
 'DateSignedNEWInformedConsentFoDate',
 'InterferonGammaReleaseAssayIGRDate',
 'OGTTTestStartTime',
 'MMTTTestStartTime',
 'TimeOfCollection',
 'TimeResultsProcessedByLab',
 'clinicalcenternumber_missing_indicator',
 'AgeOfRelativeWithT1D2_1_missing_indicator',
 'AgeOfOnsetInRelativeWithT1D2_1_missing_indicator',
 'AgeRelativeWithT1DStartedIn2_1_missing_indicator',
 'AgeOfRelativeWithT1D3_1_missing_indicator',
 'AgeOfOnsetInRelativeWithT1D3_1_missing_indicator',
 'AgeRelativeWithT1DStartedIn3_1_missing_indicator',
 'AgeOfRelativeWithT1D4_1_missing_indicator',
 'AgeOfOnsetInRelativeWithT1D4_1_missing_indicator',
 'AgeRelativeWithT1DStartedIn4_1_missing_indicator',
 'SeatedArmBPSystolic_missing_indicator',
 'SeatedArmBPDiastolic_missing_indicator',
 'SeatedHeartRate_missing_indicator',
 'SeatedRespiratoryRate_missing_indicator']

# %%
import pandas as pd
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df=pd.read_csv('data_dictionary.csv')

# %%
df['Variable Name'].unique()
# Out:
# array(['Visit', '_15Aug2011ConsentForResidualSa', 'WhichProtocolVersion',
#        'ProtocolVersion', 'RBCResultsNormal',
#        'RBCResultAbormalClinicallySign', 'HemoglobinResultsNormal',
#        'HemoglobinResultAbormalClinica', 'HematocritResultsNormal',
#        'HematocritResultAbormalClinica', 'MCVresultsNormal',
#        'MCVResultAbormalClinicallySign', 'PlateletCountResultsNormal2',
#        'MCHresultsNormal', 'MCHResultAbormalClinicallySign',
#        'MCHCresultsNormal', 'WBCresultsNormal',
#        'WBCResultAbormalClinicallySign', 'NeutrophilsResultsNormal',
#        'NeutrophilsResultAbormalClinic', 'LymphocytesResultsNormal',
#        'LymphocytesResultAbormalClinic', 'MonocytesResultsNormal',
#        'MonocytesResultAbormalClinical', 'EosinophilsResultsNormal',
#        'EosinophilsResultAbormalClinic', 'BasophilsResultsNormal',
#        'Hastheparticipantbeentoahealth', 'Hastheparticipanthadknownconta',
#        'Hastheparticipanthadknownconta2',
# ...

# %%
b=['Visit', '_15Aug2011ConsentForResidualSa', 'WhichProtocolVersion',
       'ProtocolVersion', 'RBCResultsNormal',
       'RBCResultAbormalClinicallySign', 'HemoglobinResultsNormal',
       'HemoglobinResultAbormalClinica', 'HematocritResultsNormal',
       'HematocritResultAbormalClinica', 'MCVresultsNormal',
       'MCVResultAbormalClinicallySign', 'PlateletCountResultsNormal2',
       'MCHresultsNormal', 'MCHResultAbormalClinicallySign',
       'MCHCresultsNormal', 'WBCresultsNormal',
       'WBCResultAbormalClinicallySign', 'NeutrophilsResultsNormal',
       'NeutrophilsResultAbormalClinic', 'LymphocytesResultsNormal',
       'LymphocytesResultAbormalClinic', 'MonocytesResultsNormal',
       'MonocytesResultAbormalClinical', 'EosinophilsResultsNormal',
       'EosinophilsResultAbormalClinic', 'BasophilsResultsNormal',
       'Hastheparticipantbeentoahealth', 'Hastheparticipanthadknownconta',
       'Hastheparticipanthadknownconta2',
       'Hastheparticipantbeentestedfor', 'Hastheparticipanthadafever',
       'Hastheparticipanthadchillsasso', 'Hastheparticipanthadacough',
       'Hastheparticipanthadanydifficu', 'Hastheparticipanthadanypersist',
       'Hastheparticipanthadalossreduc', 'Hastheparticipantexperiencedvo',
       '_8Hastheparticipantbeendiagnos', 'Visit_Type', 'RelativeWithT1D',
       'DegreeOfRelative_1st', 'DegreeOfRelative_2ndor3rd',
       'HaveDiabetes', 'ParticipantLocation', 'Sex', 'Ethnicity',
       'Race_AmericanIndianorAlaskaNat', 'Race_Asian',
       'Race_BlackorAfricanAmerican', 'Race_NativeHawaiianorOtherPaci',
       'Race_Refused', 'Race_Unknownornotreported', 'Race_White',
       'Relationship', 'FirstHearAboutTrialN_ExistingTri',
       'FirstHearAboutTrialN_FamilyFrien',
       'FirstHearAboutTrialN_Brochure',
       'FirstHearAboutTrialN_Healthcarep',
       'FirstHearAboutTrialN_Tollfreepho',
       'FirstHearAboutTrialN_NewspaperMa', 'FirstHearAboutTrialN_Poster',
       'FirstHearAboutTrialN_Camp', 'FirstHearAboutTrialN_MeetingPres',
       'FirstHearAboutTrialN_RadioTV', 'FirstHearAboutTrialN_Internet',
       'FirstHearAboutTrialN_Other', 'InitialScreeningLocation',
       'InitialScreeningLocationOtherS', 'BloodSamplesFutureTestingPermi',
       'BloodTestForFindOut', 'CommunicationWhenNegAutoantibo',
       'InformedTestResultWithin', 'PermissionToControlIfTheyTestA',
       'participanthaveautoantibodies', 'OnlineScreeningReferralSource',
       'ScreeningSiteName', 'shipspecimencollectionkit',
       'selecttestkittype', 'RelativeWithT1D1_1',
       'SexOfRelativeWithT1D1_1', 'RelativeWithT1D2_1',
       'SexOfRelativeWithT1D2_1', 'RelativeWithT1D3_1',
       'SexOfRelativeWithT1D3_1', 'RelativeWithT1D4_1',
       'SexOfRelativeWithT1D4_1', 'RelativeWithT1D5_1',
       'SexOfRelativeWithT1D5_1', 'RelativeWithT1D6_1',
       'SexOfRelativeWithT1D6_1', 'RelativeWithT1D7_1',
       'SexOfRelativeWithT1D7_1', 'SexOfRelativeWithT1D8_1',
       'ParticipantDiagnosedWithT1D', 'ParticipantUsedInsulinOrOtherG',
       'ParticipantHasKnownSevereActiv', 'ParticipantPregnant',
       'PermissionForHLAgeneticTesting', 'PermissionForSampleStorage',
       'AsthmaEver', 'AsthmaWithinLastYear', 'CeliacDiseaseEver',
       'CeliacDiseaseWithinLastYear', 'InflammatoryBowelDiseaseEver',
       'InflammatoryBowelDiseaseWithin', 'AddisonsDiseaseEver',
       'AddisonsDiseaseWithinLastYear', 'VitiligoEver',
       'VitiligoWithinLastYear', 'ThyroidDiseaseEver',
       'ThyroidDiseaseWithinLastYear', 'PsoriasisEver',
       'PsoriasisWithinLastYear', 'AlopeciaEver',
       'AlopeciaWithinLastYear', 'RheumatologicEver',
       'RheumatologicWithinLastYear', 'MultipleSclerosisEver',
       'MultipleSclerosisWithinLastYea', 'OtherAutoimmuneDiseasesEver',
       'OtherAutoimmuneDiseasesWithinL', 'EverParticipatedInPreventionSt',
       'ParticipateInDPT1', 'AllergiesEver', 'AllergiesWithinLastYear',
       'AntibodySampleCollected', 'BetaBlockers',
       'BllodForDNASampleCollected', 'BloodForCellsSampleCollected',
       'BloodForRNASampleCollected', 'CancerEver', 'CancerWithinLastYear',
       'ColitisOrColonProblemsEver', 'ColitisOrColonProblemsWithinLa',
       'CongenitalHeartDiseaseEver', 'CongenitalHeartDiseaseWithinLa',
       'ConsenToContinuedStorageOfBloo', 'Corticosteroids',
       'Diphenylhydantoin', 'EpilepsyConvulsionsSeizuresEve',
       'EpilepsyConvulsionsSeizuresWit', 'HLASamplesCollected',
       'HbA1cSamplesCollected', 'HepatitisOrLiverDiseaseEver',
       'HepatitisOrLiverDiseaseWithinL', 'HighBPever',
       'HighBPwithinLastYear', 'HighcholesterolEver',
       'IVGTTSampleCollected', 'ImmunosuppressiveTherapies',
       'InfectiousMononucleosisEver', 'InfectiousMononucleosisWithinL',
       'Niacin', 'OGTTSampleCollected', 'ParticipantHasOneRelativeWithT',
       'ParticipantUsedImmunosuppresiv', 'ParticipantUsingImmunosuppresi',
       'PerniciousAnemiaEver', 'PerniciousAnemiaWithinLastYear',
       'PlasmaSampleCollected', 'PotassiumDepletingDiurectics',
       'SerumForProteomicsSampleCollec', 'UlcerEver',
       'UlcerWithinLastYear', 'SelectStudyForPreventionOfT1D',
       'TestingPlaceForAutoAntibodyOut', 'IsHeightMeasured',
       'IsWeightMeasured', 'LimitedLifeExpectancyOrImmunos',
       'AsthmaWithinLast6Months', 'CeliacDiseaseWithinLast6Months',
       'AddisonsDiseaseWithinLast6Months', 'VitiligoWithinLast6Months',
       'ThyroidDiseaseWithinLast6Months', 'PsoriasisWithinLast6Months',
       'AlopeciaWithinLast6Months', 'RheumatologicWithinLast6Months',
       'AllergiesWithinLast6Months', 'CancerWithinLast6Months',
       'UlcerWithinLast6Months', 'HighBPwithinLast6Months',
       'PerniciousAnemiaWithinLast6Mo', 'MultipleSclerosisWithinLast6Mo',
       'hyperglycemia', 'immunomodulatory', 'systemicsteroids',
       'Metformin', 'Thiazolidinediones', 'AlphaGlucosidaseInhibitors',
       'OtherGlucoseLoweringAgents', 'SerumMechanisticSerumSampleCol',
       'WholeBloodPBMCPlasmaSampleColl', 'participantdiagnosedT1D',
       'IsParticipantPregnant', 'SignedMonitoringConsentProtoco',
       'HighCholesterolWithinLast6Months', 'Meglitinides',
       'HighCholestrolWithinLast6Months', 'Meglinitides', 'CurrentPhase',
       'Status', 'HospitalizedSinceLastVisit', 'OtherChronicDiseases',
       'HaveHadComplicationsFromYourDi', 'HowIsWeightObtained',
       'HowIsHeightObtained', 'SubjectUsingCGMS',
       'AreThere3GlucoseValuesAvailabl', 'InsulDoseInfoAvailableFor3Days',
       'AvgRecordedFastingGlucoses_unit', 'AvgAllRecordedGlucoses_unit',
       'LowestGlucose_unitl', 'HighestGlucose_unit',
       'InsulinRoutineDaily', 'RememberValueOfMostRecentHbA1c',
       'SeizuresFaintingLowBloodGlucos', 'HospitalizationsForHighGlucose',
       'RequiredSpecimensCollected', 'IfSpecimensNotCollec_Other',
       'OGTTCollected', 'MMTTCollected', 'AreYouUsingInjections',
       'InsulinPump', 'DiagnosedAutoImmuneDisease', 'Asthma', 'Allergies',
       'Eczema', 'OtherInfections', 'Other', 'HeentFindings',
       'NeckThyroidFindings', 'HeartFindings', 'MusculoskeletalFindings',
       'GenitaliaFindings', 'AbdomenFindings', 'LymphaticsFindings',
       'SkinFindings', 'NeurologicFindings', 'OtherFindings',
       'ReproductiveChildbearingPotent', 'UrinePregnancyTest',
       'UrinePregnancyTestPositive', 'PlateletCountNotDone', 'MCHNotDone',
       'MCHCNotDone', 'NeutrophilsNotDone', 'LymphocytesNotDone',
       'MonocytesNotDone', 'EosinophilsNotDone', 'BasophilsNotDone',
       'Subject18', 'ReceivedInfluenzaVaccination',
       'EvidenceOfTuberculosisInfectio', 'UseImmunosuppressiveAgents',
       'ComplicatedMedIssuesOrAbnormal', 'Gender', 'CollectBloodSamples',
       'EligibileToBeScreenedForTheStu', 'SexGenderPerson',
       'HospitalizedOtherthanDiabetes', 'AdmittedHospitalDiagnosis',
       'IGRATestPositive', 'PregTestPos', 'FebrileIllness10Days',
       'ExacerbationOfCRS', 'FeverPresent',
       'SkinRashHypersentivityPresent', 'FatigueMalaisePresent',
       'DizyLightHeadedPresent', 'NauseeVomitPresent',
       'HypotensionPresent', 'HypertensionPresent', 'HeadcahePresent',
       'IVinfiltrationPresent', 'InfusionRelatedEventAnaphylaxi',
       'InfusionRelatedEventOther', 'FullDoseInfused',
       'AnyProblemsRecievingStudyDrugt', 'AcetaminophenGivenToParticipan',
       'DiphenhydramineDoseGiven', 'AnyOtherMedications', 'Color',
       'Appearance', 'Leukocytes', 'Nitrite', 'Protein', 'Glucose',
       'Ketones', 'Urobilinogen', 'Bilirubin', 'Blood', 'Rbcnotdone',
       'HemoglobinNotDone', 'HematocritNotDone', 'MCVNotDone',
       'WBCNotDone', 'Doestheparticipanthavereproduc',
       'Wasaurinepregnancytestcomplete', 'Wasthetestresultpositive',
       'bloodpressureDiastolicNotDone', 'WeightNotDone', 'HeightNotDone',
       'Wasaphysicalexamperformedatthi', 'HEENT', 'NeckThyroid', 'Heart',
       'Lungs', 'Pulses', 'Musculoskeletal', 'Genitalia', 'Abdomen',
       'Lymphatics', 'Skin', 'Neurologic', 'GivenStudyDrugDoseInClinic',
       'SignsOfHypoglycemia', 'OtherProblems', 'StudyDrugReturned',
       'StudyDrugDispensed', 'ParticipantReceiveStudyDrug',
       'MedicationPackNumber1_1', 'LotNumber1_1',
       'MedicationPackNumber2_1', 'LotNumber2_1',
       'MedicationPackNumber3_1', 'LotNumber3_1', 'UnusualCircumstances',
       'STHavetherebeenanychangesinhea', 'STHavetherebeenanychangesincon',
       'STIstheparticipantcurrentlytak', 'STWastheparticipantcontactedat',
       'Height_cm_units', 'Weight_kg_units',
       'DateResultsReportedByLabUnknow', 'Date_of_Registration',
       'RememberDateOfMostRecentHbA1c', 'DateOfRegistration',
       'DiabeticKetoacidosisTimeOfDiag', 'MethylprednisoneGivenDoseTimeM',
       'Spring2019ConsentDateDate', 'DateOfBloodDrawDate',
       'DateReportedDate', 'ScreeningDate', 'ConsentSignedDate',
       'DateConsentSignedDate', 'SamplesCollectionDate', 'LastHbA1cDate',
       'WrittenInformedConsentDate', 'Type1DiabetesDiagnosisDate',
       'FluVaccinationDateDate', 'DateTestsRunDate',
       'StudyDrugReturnedDate', 'StudyDrugDispensedDate', 'BirthDate',
       'DateOfBirthDate', 'HbA1crecordDateDate', 'DateRecordedDate1',
       'DateRecordedDate2', 'DateRecordedDate3',
       'ParticipantDateDispensedDate1_1',
       'ParticipantDateDispensedDate2_1',
       'ParticipantDateDispensedDate3_1',
       'MechanisticSampleCollectionDate',
       'DateSignedInformedConsentFormDate', 'OGTTTestStartTime',
       'MMTTTestStartTime', 'TimeOfCollection',
       'TimeResultsProcessedByLab', 'Visit_Dt',
       'Specimencollectionkitshipmentd',
       'DateSignedNEWInformedConsentFoDate',
       'InterferonGammaReleaseAssayIGRDate', 'MaskID', 'Age',
       'ScreeningSiteNumber', 'NumOfRelativesWithT1D',
       'AgeOfRelativeWithT1D1_1', 'AgeOfOnsetInRelativeWithT1D1_1',
       'AgeRelativeWithT1DStartedIn1_1', 'INST-10', 'PEP120', 'GLU60',
       'PEP60', 'INST0', 'INST60', 'GLU30', 'PEP30', 'INST30', 'GLU0',
       'HbA1c', 'PEP0', 'INST120', 'GLU-10', 'GLU90', 'PEP-10', 'PEP90',
       'GLU120', 'INST90', 'GLU15', 'PEP15', 'PEP240', 'GLU240', 'ZNT8',
       'ICA', 'PEP150', 'GLU180', 'IA-2H', 'GAD65H', 'PEP180', 'GLU150',
       'PEP210', 'MIAA', 'EBVVL', 'GLU210', 'CD8P', 'CD8A', 'CD4P',
       'CD4CD8', 'CD4A', 'TPRO', 'TBIL', 'SOD', 'POT', 'GLU', 'GLOIgG',
       'DBIL', 'CREA', 'CHL', 'BIC', 'ALT', 'ALP', 'ALB', 'UREA', 'AST',
       'CPEP', 'INST', 'ICA512', 'GAD65', 'INS0', 'INS120', 'INS-10',
       'INS60', 'INS30', 'INS90', 'Rbcresults', 'HemoglobinResults',
       'HematocritResults', 'MCVresults', 'PlateletCountResultsNormal',
       'MCHresults', 'MCHCresults', 'WBCresults', 'NeutrophilsResults',
       'NeutrophilsResultsOR', 'LymphocytesResults',
       'LymphocytesResultsOR', 'MonocytesResults', 'MonocytesResultsOR',
       'EosinophilsResults', 'EosinophilsResultsOR', 'BasophilsResults',
       'BasophilsResultsOR', 'clinicalcenternumber',
       'AgeOfRelativeWithT1D2_1', 'AgeOfOnsetInRelativeWithT1D2_1',
       'AgeRelativeWithT1DStartedIn2_1', 'AgeOfRelativeWithT1D3_1',
       'AgeOfOnsetInRelativeWithT1D3_1', 'AgeRelativeWithT1DStartedIn3_1',
       'AgeOfRelativeWithT1D4_1', 'AgeOfOnsetInRelativeWithT1D4_1',
       'AgeRelativeWithT1DStartedIn4_1', 'AgeOfRelativeWithT1D5_1',
       'AgeOfOnsetInRelativeWithT1D5_1', 'AgeRelativeWithT1DStartedIn5_1',
       'AgeOfRelativeWithT1D6_1', 'AgeOfOnsetInRelativeWithT1D6_1',
       'AgeRelativeWithT1DStartedIn6_1', 'SeatedArmBPSystolic',
       'SeatedArmBPDiastolic', 'SeatedHeartRate', 'SeatedRespiratoryRate',
       'WeightKg', 'HeightCm', 'TotalOfHomeBloodGlucoseOver3Da',
       'TotalOfHBGMonitoringsLessThan6', 'AvgRecordedFastingGlucoses',
       'AvgAllRecordedGlucoses', 'LowestGlucose', 'HighestGlucose',
       'AvgUnitsShortActingInsulin', 'AverageUnitsOfItermediateInsul',
       'LastHbA1cValue', 'MMTTAmountConsumed', 'MMTTTimeToConsumeBoost',
       'InsulinDoseLast24Hrs', 'CapsulesReturned', 'CapsulesDispensed',
       'RandomizationNumber', 'Height_cm', 'Weight_kg',
       'Rbcresults_missing_indicator',
       'HemoglobinResults_missing_indicator',
       'HematocritResults_missing_indicator',
       'MCVresults_missing_indicator',
       'PlateletCountResultsNormal_missing_indicator',
       'MCHresults_missing_indicator', 'MCHCresults_missing_indicator',
       'WBCresults_missing_indicator',
       'NeutrophilsResults_missing_indicator',
       'NeutrophilsResultsOR_missing_indicator',
       'LymphocytesResults_missing_indicator',
       'LymphocytesResultsOR_missing_indicator',
       'MonocytesResults_missing_indicator',
       'MonocytesResultsOR_missing_indicator',
       'EosinophilsResults_missing_indicator',
       'EosinophilsResultsOR_missing_indicator',
       'BasophilsResults_missing_indicator',
       'BasophilsResultsOR_missing_indicator',
       'clinicalcenternumber_missing_indicator',
       'AgeOfRelativeWithT1D2_1_missing_indicator',
       'AgeOfOnsetInRelativeWithT1D2_1_missing_indicator',
       'AgeRelativeWithT1DStartedIn2_1_missing_indicator',
       'AgeOfRelativeWithT1D3_1_missing_indicator',
       'AgeOfOnsetInRelativeWithT1D3_1_missing_indicator',
       'AgeRelativeWithT1DStartedIn3_1_missing_indicator',
       'AgeOfRelativeWithT1D4_1_missing_indicator',
       'AgeOfOnsetInRelativeWithT1D4_1_missing_indicator',
       'AgeRelativeWithT1DStartedIn4_1_missing_indicator',
       'AgeOfRelativeWithT1D5_1_missing_indicator',
       'AgeOfOnsetInRelativeWithT1D5_1_missing_indicator',
       'AgeRelativeWithT1DStartedIn5_1_missing_indicator',
       'AgeOfRelativeWithT1D6_1_missing_indicator',
       'AgeOfOnsetInRelativeWithT1D6_1_missing_indicator',
       'AgeRelativeWithT1DStartedIn6_1_missing_indicator',
       'SeatedArmBPSystolic_missing_indicator',
       'SeatedArmBPDiastolic_missing_indicator',
       'SeatedHeartRate_missing_indicator',
       'SeatedRespiratoryRate_missing_indicator',
       'WeightKg_missing_indicator', 'HeightCm_missing_indicator',
       'TotalOfHomeBloodGlucoseOver3Da_missing_indicator',
       'TotalOfHBGMonitoringsLessThan6_missing_indicator',
       'AvgRecordedFastingGlucoses_missing_indicator',
       'AvgAllRecordedGlucoses_missing_indicator',
       'LowestGlucose_missing_indicator',
       'HighestGlucose_missing_indicator',
       'AvgUnitsShortActingInsulin_missing_indicator',
       'AverageUnitsOfItermediateInsul_missing_indicator',
       'LastHbA1cValue_missing_indicator',
       'MMTTAmountConsumed_missing_indicator',
       'MMTTTimeToConsumeBoost_missing_indicator',
       'InsulinDoseLast24Hrs_missing_indicator',
       'CapsulesReturned_missing_indicator',
       'CapsulesDispensed_missing_indicator',
       'RandomizationNumber_missing_indicator',
       'Height_cm_missing_indicator', 'Weight_kg_missing_indicator']

# %%
a-b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 a-b
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
difference = list(set(b) - set(a))
difference
# Out:
# ['EosinophilsResultsOR',
#  'Weight_kg_missing_indicator',
#  'BasophilsResults',
#  'MCHCresults_missing_indicator',
#  'EosinophilsResults_missing_indicator',
#  'InsulinDoseLast24Hrs',
#  'PlateletCountResultsNormal_missing_indicator',
#  'AverageUnitsOfItermediateInsul',
#  'NeutrophilsResults_missing_indicator',
#  'LymphocytesResultsOR',
#  'AvgUnitsShortActingInsulin_missing_indicator',
#  'AgeRelativeWithT1DStartedIn6_1_missing_indicator',
#  'HematocritResults_missing_indicator',
#  'Weight_kg',
#  'AvgRecordedFastingGlucoses_missing_indicator',
#  'LymphocytesResults',
#  'AvgAllRecordedGlucoses_missing_indicator',
#  'LastHbA1cValue',
#  'LymphocytesResults_missing_indicator',
#  'RandomizationNumber',
#  'CapsulesDispensed',
#  'Height_cm',
#  'AgeOfRelativeWithT1D5_1_missing_indicator',
#  'MCHCresults',
#  'MMTTAmountConsumed',
#  'MCHresults',
#  'RandomizationNumber_missing_indicator',
#  'TotalOfHomeBloodGlucoseOver3Da',
#  'Height_cm_missing_indicator',
# ...

# %%
import pandas as pd
m=pd.read_csv('df_knn.csv')
# Out:
# /tmp/ipykernel_13013/2340541637.py:2: DtypeWarning: Columns (84,225,240,277,288,308,435,436,437,438,439,440,441,443,444,445,446,447,448,449,450,454,455,456,457,458) have mixed types. Specify dtype option on import or set low_memory=False.
#   m=pd.read_csv('df_knn.csv')

# %%
m
# Out:
#         MaskID  Visit    Visit_Dt  _15Aug2011ConsentForResidualSa  \
# 0       200000     51  06/29/2007                               3
# 1       200003     51  06/29/2015                               2
# 2       200004     51  08/11/2015                               2
# 3       200007     51  11/21/2016                               2
# 4       200010     51  10/21/2016                               2
# ...        ...    ...         ...                             ...
# 259059  999980     51  06/08/2016                               3
# 259060  999981     51  06/17/2013                               2
# 259061  999985     51  05/12/2005                               3
# 259062  999987     51  11/13/2014                               2
# 259063  999991     51  11/18/2020                               2
#
#         WhichProtocolVersion  ProtocolVersion  DateResultsReportedByLabUnknow  \
# 0                          2                5                             0.0
# ...
